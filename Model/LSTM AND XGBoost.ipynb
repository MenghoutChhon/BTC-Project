# %% [markdown]
# # Time series forecasting Bitcoin Price Prediction

# %% [markdown]
# ### Importing time series data with pandas
# This data contains 4707 rows and there are two columns such as Start, which is date, and Close, which is bitcoin close price. We've collected the historical price of Bitcoin from 2012 to 2024(November).

# %%
# Import with pandas 
import pandas as pd
from datetime import datetime
# Parse dates and set date column to index
df = pd.read_csv(r'C:\Users\ASUS\Desktop\Data Ethics and Privacy\BTC_Project\DataPreprocessing\data.csv')

# %%
# Sort the DataFrame by 'Start' date
df = df.sort_values(by='Start', ascending=True)

# Reset the index after sorting
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#         Start   Close
# 0  2012-01-01  5.2677
# 1  2012-01-02  5.2168
# 2  2012-01-03  4.8808
# 3  2012-01-04  5.5738
# 4  2012-01-05  6.9476

# %%
# Convert the 'Start' column to datetime format and extract the date array for Bitcoin
df['Start'] = pd.to_datetime(df['Start'])
timesteps = df['Start'].to_numpy()  # Convert 'Start' column to a NumPy array of timestamps
prices = df["Close"].to_numpy()  # Extract the 'Close' column as a NumPy array of Bitcoin prices

# %%
# Create train and test splits the right way for time series data
split_size = int(0.8 * len(prices)) # 80% train, 20% test

# Create train data splits (everything before the split)
X_train, y_train = timesteps[:split_size], prices[:split_size]

# Create test data splits (everything after the split)
X_test, y_test = timesteps[split_size:], prices[split_size:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (3765, 942, 3765, 942)

# %%
# Create a function to plot time series data
def plot_time_series(timesteps, values, format='.', start=0, end=None, label=None):
  """
  Plots a timesteps (a series of points in time) against values (a series of values across timesteps).
  
  Parameters
  ---------
  timesteps : array of timesteps
  values : array of values across time
  format : style of plot, default "."
  start : where to start the plot (setting a value will index from start of timesteps & values)
  end : where to end the plot (setting a value will index from end of timesteps & values)
  label : label to show on plot of values
  """
  # Plot the series
  plt.plot(timesteps[start:end], values[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("BTC Price")
  if label:
    plt.legend(fontsize=14) # make label bigger
  plt.grid(True)

# %% [markdown]
# The following TensorFlow functions help in calculating these metrics for model.

# %%
# Let's get TensorFlow! 
import tensorflow as tf

# %%
def mean_absolute_scaled_error(y_true, y_pred):
    """
    Implement MASE (assuming no seasonality of data).
    """
    mae = tf.reduce_mean(tf.abs(y_true - y_pred))

    # Find MAE of naive forecast (no seasonality)
    mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1]))  # Seasonality is 1 day (shifting by 1)

    return mae / mae_naive_no_season

# %%
def evaluate_preds(y_true, y_pred):
    # Ensure float32 for metric calculations
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    # Calculate various metrics
    mae = tf.reduce_mean(tf.abs(y_true - y_pred))  # Using manual MAE calculation
    mse = tf.reduce_mean(tf.square(y_true - y_pred))  # Squared error for MSE
    rmse = tf.sqrt(mse)  # Proper RMSE calculation
    mape = tf.reduce_mean(tf.abs((y_true - y_pred) / y_true))  # Custom MAPE calculation
    mase = mean_absolute_scaled_error(y_true, y_pred)

    return {
        "mae": mae.numpy(),
        "mse": mse.numpy(),
        "rmse": rmse.numpy(),
        "mape": mape.numpy(),
        "mase": mase.numpy()
    }

# %%
HORIZON = 1 # predict 1 step at a time
WINDOW_SIZE = 7 # use a week worth of timesteps to predict the horizon

# %%
# Create function to label windowed data
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# # Test out the window labelling function
# test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
# print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")

# %%
# Create function to view NumPy arrays as windows 
import numpy as np

def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
# Print our windowed data
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (4700, 4700)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [5.2677 5.2168 4.8808 5.5738 6.9476 6.6969 6.81  ] -> Label: [7.1136]
# Window: [5.2168 4.8808 5.5738 6.9476 6.6969 6.81   7.1136] -> Label: [6.3257]
# Window: [4.8808 5.5738 6.9476 6.6969 6.81   7.1136 6.3257] -> Label: [6.36]

# %%
# View the last 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i-3]} -> Label: {full_labels[i-3]}")
# Out:
# Window: [80409.97 88627.98 88164.77 90300.02 87347.45 90949.94 90543.67] -> Label: [89763.59]
# Window: [88627.98 88164.77 90300.02 87347.45 90949.94 90543.67 89763.59] -> Label: [90549.34]
# Window: [88164.77 90300.02 87347.45 90949.94 90543.67 89763.59 90549.34] -> Label: [92119.47]

# %%
# Make the train/test splits
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  This splits the full windows and labels into training and test sets and then outputs the lengths of each.
  """
  split_size = int(len(windows) * (1-test_split)) # this will default to 80% train/20% test
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %% [markdown]
# Let's take a look at our training and test datasets after applying windowing.

# %%
# This returns the number of windows and labels in the training and test sets after the split.
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (3760, 940, 3760, 940)

# %%
# Verify if they are the same (considering horizon and window size)
np.array_equal(np.squeeze(train_labels[:-HORIZON-1]), y_train[WINDOW_SIZE:])
# Out:
# True

# %%
import os

# Create a function to implement a ModelCheckpoint callback with a specific filename 
def create_model_checkpoint(model_name, save_path="model_experiments"):
  os.makedirs(save_path, exist_ok=True)  # Create the directory if it doesn't exist
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name + ".keras"), # create filepath to save model
                                            monitor="val_loss",
                                            verbose=0, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %% [markdown]
# ## Model: RNN (LSTM)
#
# - **Input Layer**: Accepts data of shape `(WINDOW_SIZE, 1)`, where `1` is the feature (e.g., Bitcoin price).
# - **LSTM Layer**: Contains 128 units with 'relu' activation to capture temporal dependencies.
# - **Dense Output Layer**: Predicts the value(s) at the desired horizon (`HORIZON`).
# - **Compilation**: The model is compiled with Mean Absolute Error (MAE) loss and Adam optimizer.
# - **Training**: The model is trained for 300 epochs with a batch size of 128, using validation data for early stopping.

# %%
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import layers 

# Custom callback to print the performance at each epoch
class PrintEpochPerformance(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch + 1}: Loss = {logs['loss']:.4f}, Val_loss = {logs['val_loss']:.4f}")

# Now, build the model as before
inputs = layers.Input(shape=(WINDOW_SIZE, 1))  # input shape with 1 feature per timestep
x = layers.LSTM(128, activation="relu")(inputs)  # LSTM layer
output = layers.Dense(HORIZON)(x)  # Output layer with horizon of 1

# Define the model
model_lstm = tf.keras.Model(inputs=inputs, outputs=output, name="model_lstm")

# Compile the model
model_lstm.compile(loss="mae", optimizer=tf.keras.optimizers.Adam())

# Fit the model
model_lstm.fit(train_windows,  # training data
         train_labels,  # target values
         epochs=300,
         verbose=0,  # Set to 0 to prevent default logging
         batch_size=32,
         validation_data=(test_windows, test_labels),
         callbacks=[
             create_model_checkpoint(model_name=model_lstm.name),
             PrintEpochPerformance()  # Add the custom callback to print performance
         ])
# Out:
# Epoch 1: Loss = 1378.8844, Val_loss = 1319.2192
# Epoch 2: Loss = 521.4671, Val_loss = 2289.3196
# Epoch 3: Loss = 510.5821, Val_loss = 1470.4973
# Epoch 4: Loss = 463.7935, Val_loss = 1927.0056
# Epoch 5: Loss = 442.8243, Val_loss = 1298.6511
# Epoch 6: Loss = 424.8572, Val_loss = 1115.4458
# Epoch 7: Loss = 423.6926, Val_loss = 1123.7043
# Epoch 8: Loss = 394.9163, Val_loss = 1281.2672
# Epoch 9: Loss = 405.3401, Val_loss = 1058.0861
# Epoch 10: Loss = 420.5057, Val_loss = 1200.2247
# Epoch 11: Loss = 376.9408, Val_loss = 1906.4210
# Epoch 12: Loss = 412.9789, Val_loss = 1393.2778
# Epoch 13: Loss = 368.5160, Val_loss = 1499.9504
# Epoch 14: Loss = 373.5031, Val_loss = 1079.2377
# Epoch 15: Loss = 349.3236, Val_loss = 924.9720
# Epoch 16: Loss = 371.9175, Val_loss = 909.1514
# Epoch 17: Loss = 349.2070, Val_loss = 1019.7366
# Epoch 18: Loss = 377.0558, Val_loss = 963.5140
# Epoch 19: Loss = 338.8221, Val_loss = 1517.1573
# Epoch 20: Loss = 377.5217, Val_loss = 1054.7853
# Epoch 21: Loss = 343.7904, Val_loss = 1611.1412
# Epoch 22: Loss = 333.6025, Val_loss = 1506.8138
# Epoch 23: Loss = 360.5663, Val_loss = 1204.4418
# Epoch 24: Loss = 333.3794, Val_loss = 886.9468
# Epoch 25: Loss = 337.8918, Val_loss = 947.1050
# Epoch 26: Loss = 322.2709, Val_loss = 886.3957
# Epoch 27: Loss = 316.8626, Val_loss = 887.9091
# Epoch 28: Loss = 323.1547, Val_loss = 1200.9646
# Epoch 29: Loss = 331.7135, Val_loss = 937.1917
# Epoch 30: Loss = 316.1807, Val_loss = 1078.0487
# Epoch 31: Loss = 293.0664, Val_loss = 894.3626
# Epoch 32: Loss = 295.6872, Val_loss = 803.7300
# Epoch 33: Loss = 304.8013, Val_loss = 1115.8557
# Epoch 34: Loss = 321.9262, Val_loss = 910.4914
# Epoch 35: Loss = 299.2889, Val_loss = 811.5516
# Epoch 36: Loss = 297.8759, Val_loss = 805.0340
# Epoch 37: Loss = 299.7728, Val_loss = 969.9377
# Epoch 38: Loss = 292.5670, Val_loss = 1114.3390
# Epoch 39: Loss = 303.7566, Val_loss = 791.5336
# Epoch 40: Loss = 300.2855, Val_loss = 848.8454
# Epoch 41: Loss = 294.2550, Val_loss = 833.2402
# Epoch 42: Loss = 302.0247, Val_loss = 1038.5210
# Epoch 43: Loss = 282.3773, Val_loss = 800.0371
# Epoch 44: Loss = 284.9167, Val_loss = 786.4105
# Epoch 45: Loss = 293.5724, Val_loss = 911.8956
# Epoch 46: Loss = 309.4580, Val_loss = 779.2561
# Epoch 47: Loss = 330.9159, Val_loss = 778.2874
# Epoch 48: Loss = 317.5922, Val_loss = 943.5732
# Epoch 49: Loss = 288.5427, Val_loss = 927.3597
# Epoch 50: Loss = 291.3585, Val_loss = 980.8843
# Epoch 51: Loss = 279.5329, Val_loss = 801.7281
# Epoch 52: Loss = 268.6741, Val_loss = 1000.2033
# Epoch 53: Loss = 287.6013, Val_loss = 1066.3220
# Epoch 54: Loss = 277.6709, Val_loss = 826.6157
# Epoch 55: Loss = 291.0012, Val_loss = 1157.3473
# Epoch 56: Loss = 273.8565, Val_loss = 828.1162
# Epoch 57: Loss = 280.2144, Val_loss = 755.2297
# Epoch 58: Loss = 274.9054, Val_loss = 740.5402
# Epoch 59: Loss = 276.4071, Val_loss = 753.0528
# Epoch 60: Loss = 262.9844, Val_loss = 1236.4890
# Epoch 61: Loss = 295.6435, Val_loss = 882.6244
# Epoch 62: Loss = 258.5625, Val_loss = 815.2672
# Epoch 63: Loss = 265.2735, Val_loss = 844.8860
# Epoch 64: Loss = 263.1961, Val_loss = 889.5315
# Epoch 65: Loss = 267.1081, Val_loss = 810.9449
# Epoch 66: Loss = 264.4138, Val_loss = 863.7156
# Epoch 67: Loss = 285.4158, Val_loss = 748.3439
# Epoch 68: Loss = 270.4267, Val_loss = 741.3885
# Epoch 69: Loss = 277.4432, Val_loss = 1016.6028
# Epoch 70: Loss = 272.2227, Val_loss = 756.0485
# Epoch 71: Loss = 274.8010, Val_loss = 856.5347
# Epoch 72: Loss = 274.9803, Val_loss = 747.5023
# Epoch 73: Loss = 273.1302, Val_loss = 799.2628
# Epoch 74: Loss = 286.8682, Val_loss = 955.6799
# Epoch 75: Loss = 283.7435, Val_loss = 741.8044
# Epoch 76: Loss = 268.4124, Val_loss = 859.2203
# Epoch 77: Loss = 276.2148, Val_loss = 777.9474
# Epoch 78: Loss = 273.0730, Val_loss = 833.2089
# Epoch 79: Loss = 285.9650, Val_loss = 746.5935
# Epoch 80: Loss = 266.7228, Val_loss = 779.6045
# Epoch 81: Loss = 280.2782, Val_loss = 754.1934
# Epoch 82: Loss = 267.1938, Val_loss = 1068.5538
# Epoch 83: Loss = 262.2177, Val_loss = 742.9510
# Epoch 84: Loss = 269.2605, Val_loss = 741.3758
# Epoch 85: Loss = 261.8964, Val_loss = 754.6226
# Epoch 86: Loss = 266.6641, Val_loss = 839.7413
# Epoch 87: Loss = 265.4649, Val_loss = 896.7234
# Epoch 88: Loss = 264.7206, Val_loss = 783.9876
# Epoch 89: Loss = 261.9654, Val_loss = 1282.9495
# Epoch 90: Loss = 271.0523, Val_loss = 858.7426
# Epoch 91: Loss = 272.5136, Val_loss = 745.0729
# Epoch 92: Loss = 280.1173, Val_loss = 771.1229
# Epoch 93: Loss = 270.0463, Val_loss = 762.0940
# Epoch 94: Loss = 263.4157, Val_loss = 847.1174
# Epoch 95: Loss = 283.7660, Val_loss = 828.3602
# Epoch 96: Loss = 282.4820, Val_loss = 796.4172
# Epoch 97: Loss = 265.5191, Val_loss = 745.2926
# Epoch 98: Loss = 264.9991, Val_loss = 749.2169
# Epoch 99: Loss = 266.7448, Val_loss = 757.3891
# Epoch 100: Loss = 265.3979, Val_loss = 780.2239
# Epoch 101: Loss = 265.2852, Val_loss = 741.4974
# Epoch 102: Loss = 266.9148, Val_loss = 873.6467
# Epoch 103: Loss = 261.1802, Val_loss = 753.6190
# Epoch 104: Loss = 264.8780, Val_loss = 777.1243
# Epoch 105: Loss = 264.9751, Val_loss = 772.7838
# Epoch 106: Loss = 268.7589, Val_loss = 918.3447
# Epoch 107: Loss = 278.0681, Val_loss = 768.9286
# Epoch 108: Loss = 267.0362, Val_loss = 955.0177
# Epoch 109: Loss = 262.7386, Val_loss = 790.5956
# Epoch 110: Loss = 263.8317, Val_loss = 742.7982
# Epoch 111: Loss = 259.7554, Val_loss = 766.0171
# Epoch 112: Loss = 260.1262, Val_loss = 785.1829
# Epoch 113: Loss = 262.5226, Val_loss = 743.8468
# Epoch 114: Loss = 265.4862, Val_loss = 773.2343
# Epoch 115: Loss = 276.2126, Val_loss = 757.0648
# Epoch 116: Loss = 269.0121, Val_loss = 790.1857
# Epoch 117: Loss = 264.6434, Val_loss = 790.0051
# Epoch 118: Loss = 273.6665, Val_loss = 776.0110
# Epoch 119: Loss = 260.9526, Val_loss = 794.6682
# Epoch 120: Loss = 262.4247, Val_loss = 799.9640
# Epoch 121: Loss = 265.5555, Val_loss = 771.5634
# Epoch 122: Loss = 268.6555, Val_loss = 758.3515
# Epoch 123: Loss = 268.5775, Val_loss = 996.4494
# Epoch 124: Loss = 265.3159, Val_loss = 769.1711
# Epoch 125: Loss = 268.0606, Val_loss = 838.8848
# Epoch 126: Loss = 272.4232, Val_loss = 754.5157
# Epoch 127: Loss = 268.3152, Val_loss = 750.6901
# Epoch 128: Loss = 264.2645, Val_loss = 846.0354
# Epoch 129: Loss = 267.8976, Val_loss = 832.6270
# Epoch 130: Loss = 269.3742, Val_loss = 756.3189
# Epoch 131: Loss = 280.5002, Val_loss = 1073.4398
# Epoch 132: Loss = 261.6629, Val_loss = 749.6553
# Epoch 133: Loss = 266.1829, Val_loss = 862.1155
# Epoch 134: Loss = 271.9176, Val_loss = 888.7892
# Epoch 135: Loss = 264.7686, Val_loss = 758.4940
# Epoch 136: Loss = 261.1867, Val_loss = 742.2422
# Epoch 137: Loss = 260.0914, Val_loss = 780.8085
# Epoch 138: Loss = 277.1369, Val_loss = 754.0843
# Epoch 139: Loss = 268.4184, Val_loss = 750.5233
# Epoch 140: Loss = 261.0529, Val_loss = 870.3955
# Epoch 141: Loss = 265.2810, Val_loss = 877.9774
# Epoch 142: Loss = 265.6687, Val_loss = 744.5754
# Epoch 143: Loss = 270.6192, Val_loss = 750.5640
# Epoch 144: Loss = 261.8534, Val_loss = 826.7781
# Epoch 145: Loss = 265.5724, Val_loss = 757.0483
# Epoch 146: Loss = 279.3454, Val_loss = 754.2699
# Epoch 147: Loss = 267.6832, Val_loss = 753.0703
# Epoch 148: Loss = 265.6026, Val_loss = 766.7990
# Epoch 149: Loss = 285.9558, Val_loss = 1043.2784
# Epoch 150: Loss = 272.4205, Val_loss = 831.8989
# Epoch 151: Loss = 265.1485, Val_loss = 744.0704
# Epoch 152: Loss = 269.0311, Val_loss = 775.6705
# Epoch 153: Loss = 269.9122, Val_loss = 745.8464
# Epoch 154: Loss = 268.0371, Val_loss = 787.9629
# Epoch 155: Loss = 264.3577, Val_loss = 795.3295
# Epoch 156: Loss = 269.2249, Val_loss = 763.6097
# Epoch 157: Loss = 269.6445, Val_loss = 756.1937
# Epoch 158: Loss = 265.5938, Val_loss = 750.0366
# Epoch 159: Loss = 264.3308, Val_loss = 743.3842
# Epoch 160: Loss = 258.8268, Val_loss = 885.1956
# Epoch 161: Loss = 264.9960, Val_loss = 746.4461
# Epoch 162: Loss = 263.0611, Val_loss = 817.8589
# Epoch 163: Loss = 264.0687, Val_loss = 743.0362
# Epoch 164: Loss = 265.4509, Val_loss = 742.9203
# Epoch 165: Loss = 266.2361, Val_loss = 807.4860
# Epoch 166: Loss = 268.3892, Val_loss = 794.1509
# Epoch 167: Loss = 262.3465, Val_loss = 831.6263
# Epoch 168: Loss = 270.9658, Val_loss = 757.0072
# Epoch 169: Loss = 265.2132, Val_loss = 757.4167
# Epoch 170: Loss = 258.5644, Val_loss = 743.5582
# Epoch 171: Loss = 258.9567, Val_loss = 742.9184
# Epoch 172: Loss = 263.8363, Val_loss = 747.4479
# Epoch 173: Loss = 270.0950, Val_loss = 751.5068
# Epoch 174: Loss = 272.7675, Val_loss = 861.0760
# Epoch 175: Loss = 270.2415, Val_loss = 741.6469
# Epoch 176: Loss = 262.2540, Val_loss = 747.7045
# Epoch 177: Loss = 270.5095, Val_loss = 847.3967
# Epoch 178: Loss = 264.1939, Val_loss = 883.1941
# Epoch 179: Loss = 267.5116, Val_loss = 904.6553
# Epoch 180: Loss = 260.5990, Val_loss = 811.8890
# Epoch 181: Loss = 262.9066, Val_loss = 756.1234
# Epoch 182: Loss = 258.8430, Val_loss = 898.1950
# Epoch 183: Loss = 267.3167, Val_loss = 766.1349
# Epoch 184: Loss = 261.8260, Val_loss = 741.7872
# Epoch 185: Loss = 268.3109, Val_loss = 757.8531
# Epoch 186: Loss = 258.6486, Val_loss = 798.5212
# Epoch 187: Loss = 267.1473, Val_loss = 839.9374
# Epoch 188: Loss = 262.1590, Val_loss = 743.4214
# Epoch 189: Loss = 264.0973, Val_loss = 742.4137
# Epoch 190: Loss = 263.5085, Val_loss = 746.3226
# Epoch 191: Loss = 260.6680, Val_loss = 748.4248
# Epoch 192: Loss = 259.6691, Val_loss = 742.0936
# Epoch 193: Loss = 258.7276, Val_loss = 740.2246
# Epoch 194: Loss = 258.7980, Val_loss = 745.8968
# Epoch 195: Loss = 266.5330, Val_loss = 792.2938
# Epoch 196: Loss = 263.4527, Val_loss = 1017.1376
# Epoch 197: Loss = 274.2607, Val_loss = 871.2425
# Epoch 198: Loss = 264.6567, Val_loss = 747.2844
# Epoch 199: Loss = 271.6599, Val_loss = 743.8384
# Epoch 200: Loss = 264.5872, Val_loss = 817.3705
# Epoch 201: Loss = 266.5548, Val_loss = 887.6196
# Epoch 202: Loss = 277.6840, Val_loss = 743.3442
# Epoch 203: Loss = 260.9693, Val_loss = 882.3231
# Epoch 204: Loss = 261.4326, Val_loss = 746.2767
# Epoch 205: Loss = 258.5504, Val_loss = 796.1286
# Epoch 206: Loss = 259.9601, Val_loss = 766.2138
# Epoch 207: Loss = 268.4508, Val_loss = 742.4590
# Epoch 208: Loss = 273.8963, Val_loss = 749.9445
# Epoch 209: Loss = 259.7642, Val_loss = 835.1742
# Epoch 210: Loss = 265.1438, Val_loss = 752.3314
# Epoch 211: Loss = 266.0886, Val_loss = 738.9650
# Epoch 212: Loss = 262.4921, Val_loss = 773.3619
# Epoch 213: Loss = 262.6302, Val_loss = 740.3389
# Epoch 214: Loss = 265.3297, Val_loss = 739.1304
# Epoch 215: Loss = 266.9510, Val_loss = 796.3867
# Epoch 216: Loss = 261.9913, Val_loss = 756.8087
# Epoch 217: Loss = 258.2155, Val_loss = 750.0891
# Epoch 218: Loss = 260.1983, Val_loss = 778.6400
# Epoch 219: Loss = 261.3497, Val_loss = 1039.7249
# Epoch 220: Loss = 262.7774, Val_loss = 740.8145
# Epoch 221: Loss = 263.5056, Val_loss = 812.1322
# Epoch 222: Loss = 264.1988, Val_loss = 762.0206
# Epoch 223: Loss = 263.7998, Val_loss = 850.6571
# Epoch 224: Loss = 265.0306, Val_loss = 907.2477
# Epoch 225: Loss = 263.4066, Val_loss = 743.2875
# Epoch 226: Loss = 259.1943, Val_loss = 751.0354
# Epoch 227: Loss = 268.1469, Val_loss = 1054.3787
# Epoch 228: Loss = 269.8604, Val_loss = 740.5441
# Epoch 229: Loss = 263.5286, Val_loss = 753.3434
# Epoch 230: Loss = 255.8508, Val_loss = 775.9587
# Epoch 231: Loss = 264.4554, Val_loss = 1088.6427
# Epoch 232: Loss = 261.2802, Val_loss = 998.1355
# Epoch 233: Loss = 262.5119, Val_loss = 986.0817
# Epoch 234: Loss = 262.2062, Val_loss = 849.1819
# Epoch 235: Loss = 264.7003, Val_loss = 747.9305
# Epoch 236: Loss = 261.3531, Val_loss = 864.5626
# Epoch 237: Loss = 257.1074, Val_loss = 761.5244
# Epoch 238: Loss = 258.1191, Val_loss = 739.9880
# Epoch 239: Loss = 260.8118, Val_loss = 808.3043
# Epoch 240: Loss = 259.9653, Val_loss = 848.5901
# Epoch 241: Loss = 265.0604, Val_loss = 806.5768
# Epoch 242: Loss = 261.1275, Val_loss = 1008.4704
# Epoch 243: Loss = 263.2536, Val_loss = 739.9520
# Epoch 244: Loss = 265.3365, Val_loss = 747.7811
# Epoch 245: Loss = 257.2802, Val_loss = 786.3805
# Epoch 246: Loss = 266.4466, Val_loss = 845.0173
# Epoch 247: Loss = 267.9075, Val_loss = 741.1082
# Epoch 248: Loss = 262.5865, Val_loss = 739.3860
# Epoch 249: Loss = 275.0966, Val_loss = 766.0452
# Epoch 250: Loss = 259.6875, Val_loss = 782.3509
# Epoch 251: Loss = 272.9095, Val_loss = 764.1746
# Epoch 252: Loss = 260.4637, Val_loss = 827.2064
# Epoch 253: Loss = 261.1260, Val_loss = 745.5634
# Epoch 254: Loss = 259.4933, Val_loss = 760.8881
# Epoch 255: Loss = 263.4607, Val_loss = 760.7131
# Epoch 256: Loss = 264.7968, Val_loss = 778.8012
# Epoch 257: Loss = 267.0384, Val_loss = 748.0351
# Epoch 258: Loss = 260.4517, Val_loss = 740.8038
# Epoch 259: Loss = 259.9298, Val_loss = 765.0244
# Epoch 260: Loss = 271.4034, Val_loss = 834.2689
# Epoch 261: Loss = 262.7191, Val_loss = 744.8301
# Epoch 262: Loss = 268.1460, Val_loss = 835.1226
# Epoch 263: Loss = 257.4117, Val_loss = 746.6056
# Epoch 264: Loss = 258.2643, Val_loss = 744.2052
# Epoch 265: Loss = 258.3407, Val_loss = 748.8624
# Epoch 266: Loss = 263.1332, Val_loss = 742.8264
# Epoch 267: Loss = 262.5518, Val_loss = 791.1707
# Epoch 268: Loss = 260.7491, Val_loss = 783.4025
# Epoch 269: Loss = 267.4748, Val_loss = 778.6124
# Epoch 270: Loss = 262.7191, Val_loss = 740.9375
# Epoch 271: Loss = 263.2100, Val_loss = 768.3112
# Epoch 272: Loss = 257.8408, Val_loss = 740.7929
# Epoch 273: Loss = 260.2773, Val_loss = 820.1943
# Epoch 274: Loss = 263.4233, Val_loss = 779.8824
# Epoch 275: Loss = 265.3640, Val_loss = 843.8030
# Epoch 276: Loss = 263.5563, Val_loss = 755.1160
# Epoch 277: Loss = 265.5717, Val_loss = 763.6849
# Epoch 278: Loss = 260.0698, Val_loss = 975.5070
# Epoch 279: Loss = 266.5495, Val_loss = 783.5468
# Epoch 280: Loss = 270.4313, Val_loss = 742.9747
# Epoch 281: Loss = 263.6190, Val_loss = 779.9587
# Epoch 282: Loss = 258.4554, Val_loss = 862.8141
# Epoch 283: Loss = 259.3345, Val_loss = 783.0742
# Epoch 284: Loss = 265.8963, Val_loss = 798.6390
# Epoch 285: Loss = 263.4194, Val_loss = 1087.0039
# Epoch 286: Loss = 258.2133, Val_loss = 754.3217
# Epoch 287: Loss = 265.3726, Val_loss = 747.8005
# Epoch 288: Loss = 259.5315, Val_loss = 754.1337
# Epoch 289: Loss = 267.3448, Val_loss = 741.7904
# Epoch 290: Loss = 257.1369, Val_loss = 759.1389
# Epoch 291: Loss = 258.4282, Val_loss = 876.7688
# Epoch 292: Loss = 257.7658, Val_loss = 816.6447
# Epoch 293: Loss = 266.9692, Val_loss = 779.6903
# Epoch 294: Loss = 257.5591, Val_loss = 744.5994
# Epoch 295: Loss = 258.8384, Val_loss = 745.5855
# Epoch 296: Loss = 261.0051, Val_loss = 742.8140
# Epoch 297: Loss = 261.5625, Val_loss = 796.3934
# Epoch 298: Loss = 257.7507, Val_loss = 782.6609
# Epoch 299: Loss = 261.2439, Val_loss = 818.1443
# Epoch 300: Loss = 261.6745, Val_loss = 778.9529

# %%
# Evaluate LSTM model on the test data 
model_lstm.evaluate(test_windows, test_labels)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 647.2621
# 778.952880859375

# %%
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
  model: trained model 
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  return tf.squeeze(forecast) # return 1D array of predictions

# %%
# Make predictions with our LSTM model on the test dataset and view the results
model_lstm_preds = make_preds(model_lstm, test_windows)
model_lstm_preds[:10]
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([39743.832, 40717.816, 38381.02 , 39491.78 , 39971.418, 38917.27 ,
#        37965.027, 38690.16 , 38756.24 , 38035.   ], dtype=float32)>

# %%
# Evaluate preds many layer
model_lstm_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                 y_pred=model_lstm_preds)
model_lstm_results
# Out:
# {'mae': 778.9529,
#  'mse': 1463567.2,
#  'rmse': 1209.7798,
#  'mape': 0.020163815,
#  'mase': 1.0485653}

# %%
# LSTM model predictions
offset = 300  # Adjust this based on your data
plt.figure(figsize=(10, 7))

# Make predictions for training data
model_lstm_train_preds = make_preds(model_lstm, train_windows)  # Predictions for the training data

# Plot the training data and predictions
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels, start=offset, label="Train Data")
plot_time_series(timesteps=X_train[-len(train_windows):], values=model_lstm_train_preds, start=offset, format="-", label="Model LSTM Train Predictions")

# Add labels and legend
plt.title("Training LSTM Predictions")
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Our lstm model predictions
offset = 300
plt.figure(figsize=(10, 7))
# Account for the test_window offset and index into test_labels to ensure correct plotting
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], start=offset, label="Test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_lstm_preds, start=offset, format="-", label="model_lstm_preds")

# %%
model_lstm.summary()
# Out:
# Model: "model_lstm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 7, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 200,069 (781.52 KB)
#  Trainable params: 66,689 (260.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 133,380 (521.02 KB)

# %%
# from tensorflow.keras.models import load_model

# model_path = r'C:\Users\ASUS\Desktop\Data Ethics and Privacy\BTC_Project\Model\model_experiments\model_lstm.keras'
# model = load_model(model_path)

# %% [markdown]
# ### XGBoost Model

# %%
import xgboost as xgb

# Custom callback to print the performance at each epoch
class PrintEpochPerformance(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch + 1}: Loss = {logs['loss']:.4f}, Val_loss = {logs['val_loss']:.4f}")

# %%
# Function to implement a ModelCheckpoint-like mechanism for XGBoost
def create_model_checkpoint(model_name, save_path="model_experiments"):
    os.makedirs(save_path, exist_ok=True)  # Ensure save directory exists
    return os.path.join(save_path, model_name + ".json")  # Save as .json for XGBoost

# %%
# Convert to DMatrix format for XGBoost
dtrain = xgb.DMatrix(train_windows, label=train_labels)
dtest = xgb.DMatrix(test_windows, label=test_labels)

# %%
params = {
    "objective": "reg:squarederror",
    "eval_metric": "mae",  # Can also try 'rmse'
    "max_depth": 6,  # Start with 6, tune within 4-10
    "eta": 0.05,  # Slightly increased learning rate
    "subsample": 0.8,  # Adjusted for diversity in rows
    "colsample_bytree": 0.8,  # Adjusted for diversity in features
    "lambda": 1.0,  # L2 regularization
    "alpha": 0.1,  # L1 regularization
    "seed": 42
}

# %%
# Custom training loop for XGBoost with callbacks
model_name = "xgboost_model"
checkpoint_path = create_model_checkpoint(model_name)

num_boost_round = 300  # Matches LSTM epochs
early_stopping_rounds = 10  # Early stopping patience
evals = [(dtrain, "train"), (dtest, "val")]

# %%
# Initialize variables for tracking the best model
best_val_loss = float("inf")
best_model = None

# %%
from sklearn.metrics import mean_absolute_error

# %%
# Training loop
for epoch in range(num_boost_round):
    # Train for one round
    model = xgb.train(
        params=params,
        dtrain=dtrain,
        num_boost_round=epoch + 1,
        evals=evals,
        early_stopping_rounds=early_stopping_rounds,
        verbose_eval=False
    )

    # Calculate losses
    train_pred = model.predict(dtrain)
    val_pred = model.predict(dtest)
    train_loss = mean_absolute_error(train_labels, train_pred)
    val_loss = mean_absolute_error(test_labels, val_pred)

    # Custom callback to print performance
    logs = {"loss": train_loss, "val_loss": val_loss}
    PrintEpochPerformance().on_epoch_end(epoch, logs)

    # Save the best model
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
        model.save_model(checkpoint_path)

print("Training complete. Best model saved.")
# Out:
# Epoch 1: Loss = 9719.6779, Val_loss = 28108.1014
# Epoch 2: Loss = 9238.5984, Val_loss = 26820.4837
# Epoch 3: Loss = 8780.7276, Val_loss = 25516.3681
# Epoch 4: Loss = 8345.1206, Val_loss = 24300.4118
# Epoch 5: Loss = 7932.4704, Val_loss = 23150.0066
# Epoch 6: Loss = 7539.1834, Val_loss = 22024.5136
# Epoch 7: Loss = 7166.1503, Val_loss = 20981.2923
# Epoch 8: Loss = 6811.1740, Val_loss = 20008.9966
# Epoch 9: Loss = 6474.4865, Val_loss = 19071.8989
# Epoch 10: Loss = 6152.6512, Val_loss = 18194.6118
# Epoch 11: Loss = 5847.9261, Val_loss = 17319.3245
# Epoch 12: Loss = 5558.6902, Val_loss = 16507.7934
# Epoch 13: Loss = 5284.4614, Val_loss = 15746.7440
# Epoch 14: Loss = 5023.1764, Val_loss = 15043.7684
# Epoch 15: Loss = 4774.0729, Val_loss = 14370.9591
# Epoch 16: Loss = 4538.5607, Val_loss = 13727.6473
# Epoch 17: Loss = 4314.3368, Val_loss = 13080.0716
# Epoch 18: Loss = 4101.2600, Val_loss = 12471.5314
# Epoch 19: Loss = 3899.1382, Val_loss = 11898.9143
# Epoch 20: Loss = 3707.5173, Val_loss = 11361.6286
# Epoch 21: Loss = 3525.1985, Val_loss = 10825.7281
# Epoch 22: Loss = 3351.6200, Val_loss = 10303.9233
# Epoch 23: Loss = 3187.5065, Val_loss = 9831.9888
# Epoch 24: Loss = 3031.8114, Val_loss = 9399.4124
# Epoch 25: Loss = 2883.0582, Val_loss = 8975.2232
# Epoch 26: Loss = 2741.3150, Val_loss = 8584.4756
# Epoch 27: Loss = 2607.2466, Val_loss = 8209.3984
# Epoch 28: Loss = 2480.0638, Val_loss = 7853.0420
# Epoch 29: Loss = 2359.4592, Val_loss = 7497.7579
# Epoch 30: Loss = 2244.7727, Val_loss = 7156.3521
# Epoch 31: Loss = 2135.4991, Val_loss = 6827.7164
# Epoch 32: Loss = 2031.3568, Val_loss = 6525.3666
# Epoch 33: Loss = 1932.8199, Val_loss = 6256.5386
# Epoch 34: Loss = 1838.8366, Val_loss = 6000.8062
# Epoch 35: Loss = 1750.1828, Val_loss = 5754.2794
# Epoch 36: Loss = 1665.8164, Val_loss = 5538.5854
# Epoch 37: Loss = 1585.2660, Val_loss = 5321.4950
# Epoch 38: Loss = 1508.8416, Val_loss = 5124.8715
# Epoch 39: Loss = 1436.4734, Val_loss = 4940.0418
# Epoch 40: Loss = 1368.3686, Val_loss = 4775.4087
# Epoch 41: Loss = 1304.1945, Val_loss = 4615.6245
# Epoch 42: Loss = 1243.6164, Val_loss = 4459.4708
# Epoch 43: Loss = 1186.1710, Val_loss = 4317.6643
# Epoch 44: Loss = 1131.9518, Val_loss = 4186.8446
# Epoch 45: Loss = 1080.2748, Val_loss = 4070.8194
# Epoch 46: Loss = 1031.6460, Val_loss = 3961.6480
# Epoch 47: Loss = 984.9386, Val_loss = 3839.9659
# Epoch 48: Loss = 940.1773, Val_loss = 3731.3674
# Epoch 49: Loss = 898.6942, Val_loss = 3636.2702
# Epoch 50: Loss = 859.0109, Val_loss = 3543.1306
# Epoch 51: Loss = 821.8004, Val_loss = 3457.3768
# Epoch 52: Loss = 786.5804, Val_loss = 3381.9209
# Epoch 53: Loss = 753.3281, Val_loss = 3297.5571
# Epoch 54: Loss = 721.9683, Val_loss = 3221.5372
# Epoch 55: Loss = 692.0505, Val_loss = 3163.6323
# Epoch 56: Loss = 664.1857, Val_loss = 3104.6412
# Epoch 57: Loss = 637.6251, Val_loss = 3047.9379
# Epoch 58: Loss = 612.9024, Val_loss = 2994.9475
# Epoch 59: Loss = 589.0253, Val_loss = 2933.2696
# Epoch 60: Loss = 566.9567, Val_loss = 2884.4000
# Epoch 61: Loss = 545.6753, Val_loss = 2834.1401
# Epoch 62: Loss = 525.8167, Val_loss = 2789.3161
# Epoch 63: Loss = 506.9272, Val_loss = 2736.5692
# Epoch 64: Loss = 489.1855, Val_loss = 2692.7826
# Epoch 65: Loss = 472.6434, Val_loss = 2654.8240
# Epoch 66: Loss = 456.9280, Val_loss = 2614.4814
# Epoch 67: Loss = 442.7921, Val_loss = 2585.1241
# Epoch 68: Loss = 428.8281, Val_loss = 2558.7274
# Epoch 69: Loss = 415.8662, Val_loss = 2539.0682
# Epoch 70: Loss = 403.3076, Val_loss = 2522.6087
# Epoch 71: Loss = 391.5538, Val_loss = 2489.6676
# Epoch 72: Loss = 381.0417, Val_loss = 2469.2886
# Epoch 73: Loss = 371.3912, Val_loss = 2445.3478
# Epoch 74: Loss = 361.9876, Val_loss = 2427.3578
# Epoch 75: Loss = 353.2296, Val_loss = 2409.5286
# Epoch 76: Loss = 344.3417, Val_loss = 2383.5670
# Epoch 77: Loss = 336.5863, Val_loss = 2361.4644
# Epoch 78: Loss = 329.2215, Val_loss = 2349.7192
# Epoch 79: Loss = 322.0978, Val_loss = 2337.3205
# Epoch 80: Loss = 315.5838, Val_loss = 2316.5067
# Epoch 81: Loss = 309.4808, Val_loss = 2311.0713
# Epoch 82: Loss = 303.6177, Val_loss = 2297.4646
# Epoch 83: Loss = 297.8301, Val_loss = 2291.3791
# Epoch 84: Loss = 292.5273, Val_loss = 2287.3762
# Epoch 85: Loss = 287.4217, Val_loss = 2275.7133
# Epoch 86: Loss = 282.4529, Val_loss = 2264.7713
# Epoch 87: Loss = 277.8676, Val_loss = 2252.4018
# Epoch 88: Loss = 273.6492, Val_loss = 2240.3320
# Epoch 89: Loss = 269.6620, Val_loss = 2228.5292
# Epoch 90: Loss = 265.6265, Val_loss = 2221.8039
# Epoch 91: Loss = 262.1160, Val_loss = 2223.5070
# Epoch 92: Loss = 258.0721, Val_loss = 2216.8522
# Epoch 93: Loss = 254.8554, Val_loss = 2212.0222
# Epoch 94: Loss = 251.5636, Val_loss = 2200.6922
# Epoch 95: Loss = 248.6592, Val_loss = 2198.2539
# Epoch 96: Loss = 245.8598, Val_loss = 2197.5110
# Epoch 97: Loss = 243.1610, Val_loss = 2196.4681
# Epoch 98: Loss = 240.6921, Val_loss = 2194.9367
# Epoch 99: Loss = 238.3264, Val_loss = 2196.1941
# Epoch 100: Loss = 235.8013, Val_loss = 2197.7308
# Epoch 101: Loss = 233.5287, Val_loss = 2194.0666
# Epoch 102: Loss = 231.4557, Val_loss = 2196.8829
# Epoch 103: Loss = 229.2750, Val_loss = 2194.5530
# Epoch 104: Loss = 227.3937, Val_loss = 2194.3657
# Epoch 105: Loss = 225.5870, Val_loss = 2193.0042
# Epoch 106: Loss = 224.0437, Val_loss = 2193.0199
# Epoch 107: Loss = 222.3450, Val_loss = 2188.3107
# Epoch 108: Loss = 220.8521, Val_loss = 2184.5402
# Epoch 109: Loss = 218.8888, Val_loss = 2176.0157
# Epoch 110: Loss = 217.3970, Val_loss = 2164.6366
# Epoch 111: Loss = 215.9120, Val_loss = 2166.8730
# Epoch 112: Loss = 214.5169, Val_loss = 2165.7121
# Epoch 113: Loss = 213.1919, Val_loss = 2160.4711
# Epoch 114: Loss = 212.0149, Val_loss = 2160.6255
# Epoch 115: Loss = 210.7321, Val_loss = 2157.7937
# Epoch 116: Loss = 209.5834, Val_loss = 2155.6771
# Epoch 117: Loss = 208.5276, Val_loss = 2154.6983
# Epoch 118: Loss = 207.1391, Val_loss = 2156.5199
# Epoch 119: Loss = 205.9079, Val_loss = 2151.2947
# Epoch 120: Loss = 204.8349, Val_loss = 2141.5052
# Epoch 121: Loss = 203.9374, Val_loss = 2145.9338
# Epoch 122: Loss = 203.1365, Val_loss = 2139.7995
# Epoch 123: Loss = 202.2428, Val_loss = 2138.9005
# Epoch 124: Loss = 201.3469, Val_loss = 2136.3888
# Epoch 125: Loss = 200.2884, Val_loss = 2137.6676
# Epoch 126: Loss = 199.4709, Val_loss = 2135.3659
# Epoch 127: Loss = 198.8818, Val_loss = 2135.5348
# Epoch 128: Loss = 198.2439, Val_loss = 2127.9437
# Epoch 129: Loss = 197.3425, Val_loss = 2126.3211
# Epoch 130: Loss = 196.9261, Val_loss = 2123.3043
# Epoch 131: Loss = 196.0465, Val_loss = 2121.4677
# Epoch 132: Loss = 195.4693, Val_loss = 2122.0758
# Epoch 133: Loss = 194.5493, Val_loss = 2115.0417
# Epoch 134: Loss = 193.9152, Val_loss = 2108.7579
# Epoch 135: Loss = 193.2820, Val_loss = 2109.7120
# Epoch 136: Loss = 192.5672, Val_loss = 2109.0407
# Epoch 137: Loss = 192.2333, Val_loss = 2107.5342
# Epoch 138: Loss = 191.6695, Val_loss = 2109.5594
# Epoch 139: Loss = 191.3235, Val_loss = 2111.9870
# Epoch 140: Loss = 190.4283, Val_loss = 2111.8303
# Epoch 141: Loss = 189.8139, Val_loss = 2117.9385
# Epoch 142: Loss = 189.1793, Val_loss = 2121.7329
# Epoch 143: Loss = 188.4476, Val_loss = 2125.1530
# Epoch 144: Loss = 187.8894, Val_loss = 2125.7660
# Epoch 145: Loss = 187.3282, Val_loss = 2130.7508
# Epoch 146: Loss = 186.9027, Val_loss = 2130.7974
# Epoch 147: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 148: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 149: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 150: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 151: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 152: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 153: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 154: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 155: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 156: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 157: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 158: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 159: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 160: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 161: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 162: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 163: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 164: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 165: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 166: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 167: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 168: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 169: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 170: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 171: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 172: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 173: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 174: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 175: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 176: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 177: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 178: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 179: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 180: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 181: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 182: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 183: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 184: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 185: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 186: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 187: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 188: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 189: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 190: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 191: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 192: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 193: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 194: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 195: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 196: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 197: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 198: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 199: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 200: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 201: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 202: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 203: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 204: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 205: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 206: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 207: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 208: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 209: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 210: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 211: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 212: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 213: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 214: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 215: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 216: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 217: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 218: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 219: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 220: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 221: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 222: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 223: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 224: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 225: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 226: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 227: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 228: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 229: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 230: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 231: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 232: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 233: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 234: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 235: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 236: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 237: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 238: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 239: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 240: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 241: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 242: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 243: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 244: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 245: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 246: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 247: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 248: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 249: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 250: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 251: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 252: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 253: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 254: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 255: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 256: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 257: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 258: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 259: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 260: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 261: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 262: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 263: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 264: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 265: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 266: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 267: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 268: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 269: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 270: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 271: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 272: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 273: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 274: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 275: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 276: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 277: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 278: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 279: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 280: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 281: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 282: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 283: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 284: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 285: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 286: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 287: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 288: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 289: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 290: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 291: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 292: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 293: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 294: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 295: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 296: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 297: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 298: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 299: Loss = 186.5845, Val_loss = 2136.5292
# Epoch 300: Loss = 186.5845, Val_loss = 2136.5292
# Training complete. Best model saved.

# %%
# Load the best model (if needed)
loaded_model = xgb.Booster()
loaded_model.load_model(checkpoint_path)

# %%
# Predict on the test data
predictions = loaded_model.predict(dtest)
print(f"Test MAE: {mean_absolute_error(test_labels, predictions):.4f}")
# Out:
# Test MAE: 2107.5342

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.dates import DateFormatter, AutoDateLocator

# Plot predictions vs actuals for train and test datasets with dates on the x-axis
def plot_predictions(train_timesteps, train_labels, train_predictions, test_timesteps, test_labels, test_predictions):
    plt.figure(figsize=(14, 7))

    # Plot training data predictions
    plt.subplot(1, 2, 1)
    plt.plot(train_timesteps, train_labels, label="Actual Train", color="blue")
    plt.plot(train_timesteps, train_predictions, label="Predicted Train", color="red", linestyle="dashed")
    plt.title("Train Predictions vs Actual")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()

    # Format x-axis for better date display
    plt.gca().xaxis.set_major_formatter(DateFormatter("%Y-%m"))  # Format dates as "YYYY-MM"
    plt.gca().xaxis.set_major_locator(AutoDateLocator())         # Automatically adjust date spacing
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

    # Plot testing data predictions
    plt.subplot(1, 2, 2)
    plt.plot(test_timesteps, test_labels, label="Actual Test", color="blue")
    plt.plot(test_timesteps, test_predictions, label="Predicted Test", color="red", linestyle="dashed")
    plt.title("Test Predictions vs Actual")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()

    # Format x-axis for better date display
    plt.gca().xaxis.set_major_formatter(DateFormatter("%Y-%m"))  # Format dates as "YYYY-MM"
    plt.gca().xaxis.set_major_locator(AutoDateLocator())         # Automatically adjust date spacing
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

    plt.tight_layout()
    plt.show()

# Generate predictions
train_predictions = loaded_model.predict(dtrain)
test_predictions = loaded_model.predict(dtest)

# Extract timesteps for training and testing data
# Ensure X_train and X_test are in datetime format
train_timesteps = pd.to_datetime(X_train[-len(train_labels):])  # Align timesteps with train_labels
test_timesteps = pd.to_datetime(X_test[-len(test_labels):])     # Align timesteps with test_labels

# Plot the results with dates on the x-axis
plot_predictions(train_timesteps, train_labels, train_predictions, test_timesteps, test_labels, test_predictions)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the saved model
model = load_model('C:\\Users\\ASUS\\Desktop\\Data Ethics and Privacy\\BTC_Project\\Model\\model_experiments\\model_lstm.keras')  # Replace with your saved model's path

# Plot the model architecture
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

print("Model architecture saved as 'model_architecture.png'")
# Out:
# Model architecture saved as 'model_architecture.png'

# %%
import xgboost as xgb
import matplotlib.pyplot as plt

# Load the XGBoost model from the JSON file
model = xgb.Booster()
model.load_model('C:\\Users\\ASUS\\Desktop\\Data Ethics and Privacy\\BTC_Project\\Model\\model_experiments\\xgboost_model.json')

# Plot the first tree in the model with much higher resolution and a larger figure size
plt.figure(figsize=(30, 25))  # Make the figure even larger for more details
xgb.plot_tree(model, num_trees=0)
plt.gcf().set_dpi(600)  # Set DPI to 600 for extremely high resolution
plt.show()

# %%
import xgboost as xgb
import graphviz

# Load the XGBoost model from the JSON file
model = xgb.Booster()
model.load_model('C:\\Users\\ASUS\\Desktop\\Data Ethics and Privacy\\BTC_Project\\Model\\model_experiments\\xgboost_model.json')

# Convert the first tree to Graphviz format
graph = xgb.to_graphviz(model, num_trees=0)

# Render and save the tree as a PNG image
graph.render('xgboost_tree', format='png', cleanup=True)

# Show the plot (optional)
graph.view()
# Out:
# 'xgboost_tree.pdf'

# %%
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Load the XGBoost model from the JSON file
loaded_model = xgb.Booster()
loaded_model.load_model('C:\\Users\\ASUS\\Desktop\\Data Ethics and Privacy\\BTC_Project\\Model\\model_experiments\\xgboost_model.json')

# Assuming you already have dtrain (XGBoost DMatrix for training data) and dtest (for test data)
# Generate predictions
train_predictions = loaded_model.predict(dtrain)
test_predictions = loaded_model.predict(dtest)

# Get the true labels from your dtest and dtrain DMatrix
train_labels = dtrain.get_label()
test_labels = dtest.get_label()

# Compute MAE (Mean Absolute Error) for train and test datasets
train_mae = mean_absolute_error(train_labels, train_predictions)
test_mae = mean_absolute_error(test_labels, test_predictions)

# Compute MSE (Mean Squared Error)
train_mse = mean_squared_error(train_labels, train_predictions)
test_mse = mean_squared_error(test_labels, test_predictions)

# Compute RMSE (Root Mean Squared Error)
train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)

# Compute MAPE (Mean Absolute Percentage Error)
train_mape = np.mean(np.abs((train_labels - train_predictions) / train_labels))  # Avoid division by zero
test_mape = np.mean(np.abs((test_labels - test_predictions) / test_labels))

# Compute MASE (Mean Absolute Scaled Error)
# Using naive prediction based on the previous step in the time series
train_naive_pred = np.roll(train_labels, 1)
train_naive_pred[0] = np.nan  # Handle the first element as NaN
train_mase = np.mean(np.abs(train_labels - train_predictions)) / np.nanmean(np.abs(train_labels - train_naive_pred))

test_naive_pred = np.roll(test_labels, 1)
test_naive_pred[0] = np.nan  # Handle the first element as NaN
test_mase = np.mean(np.abs(test_labels - test_predictions)) / np.nanmean(np.abs(test_labels - test_naive_pred))

# Print all metrics
print(f"Test MAE: {test_mae}")
print(f"Test MSE: {test_mse}")
print(f"Test RMSE: {test_rmse}")
print(f"Test MAPE: {test_mape}")
print(f"Test MASE: {test_mase}")
# Out:
# Test MAE: 2107.534423828125
# Test MSE: 13777630.0
# Test RMSE: 3711.822998046875
# Test MAPE: 0.054759882390499115
# Test MASE: 2.8369972705841064
